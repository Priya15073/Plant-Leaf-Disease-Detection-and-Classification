# %%
#Priya Rajpurohit 2015073
#Sakshi Saini 2017092

# %%
import tensorflow_datasets as tfds
import tensorflow as tf
import matplotlib.pyplot as plt

import keras
from keras.layers.core import Layer
import keras.backend as K

from keras.models import Model
from keras.layers import Conv2D, MaxPool2D,  \
    Dropout, Dense, Input, concatenate,      \
    GlobalAveragePooling2D, AveragePooling2D,\
    Flatten

import cv2 
import numpy as np 
from keras import backend as K 
from keras.utils import np_utils

import math 
from keras.optimizers import SGD 
from keras.callbacks import LearningRateScheduler
from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
ds = tfds.load("plant_village", split=tfds.Split.TRAIN, batch_size=-1)
ds = tfds.as_numpy(ds)

images, labels = ds["image"], ds["label"]

# %%
X_train, X_test, y_train, y_test = train_test_split( images[:20000], labels[:20000], test_size=0.3, random_state=42 )
print(X_train.shape, X_test.shape)
# Out:
# (14000, 256, 256, 3) (6000, 256, 256, 3)

# %%
np.unique(y_train).shape
n = 38

y_train = np_utils.to_categorical( y_train, n)
y_test = np_utils.to_categorical( y_test, n)

X_train = X_train.astype('float32')/255
X_test = X_test.astype('float32')/255

# %%
def inception_module(x,
                     filters_1x1,
                     filters_3x3_reduce,
                     filters_3x3,
                     filters_5x5_reduce,
                     filters_5x5,
                     filters_pool_proj,
                     name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (5, 5), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
kernel_init = keras.initializers.glorot_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(224, 224, 3))

x = Conv2D(64, (7, 7), padding='same', strides=(2, 2), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(1, 1), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(192, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_3_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=192,
                     filters_3x3_reduce=96,
                     filters_3x3=208,
                     filters_5x5_reduce=16,
                     filters_5x5=48,
                     filters_pool_proj=64,
                     name='inception_4a')


x1 = AveragePooling2D((5, 5), strides=3)(x)
x1 = Conv2D(128, (1, 1), padding='same', activation='relu')(x1)
x1 = Flatten()(x1)
x1 = Dense(1024, activation='relu')(x1)
x1 = Dropout(0.7)(x1)
x1 = Dense(38, activation='softmax', name='auxilliary_output_1')(x1)

x = inception_module(x,
                     filters_1x1=160,
                     filters_3x3_reduce=112,
                     filters_3x3=224,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4b')

x = inception_module(x,
                     filters_1x1=128,
                     filters_3x3_reduce=128,
                     filters_3x3=256,
                     filters_5x5_reduce=24,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4c')

x = inception_module(x,
                     filters_1x1=112,
                     filters_3x3_reduce=144,
                     filters_3x3=288,
                     filters_5x5_reduce=32,
                     filters_5x5=64,
                     filters_pool_proj=64,
                     name='inception_4d')


x2 = AveragePooling2D((5, 5), strides=3)(x)
x2 = Conv2D(128, (1, 1), padding='same', activation='relu')(x2)
x2 = Flatten()(x2)
x2 = Dense(1024, activation='relu')(x2)
x2 = Dropout(0.7)(x2)
x2 = Dense(38, activation='softmax', name='auxilliary_output_2')(x2)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_4e')

x = MaxPool2D((3, 3), padding='same', strides=(2, 2), name='max_pool_4_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=256,
                     filters_3x3_reduce=160,
                     filters_3x3=320,
                     filters_5x5_reduce=32,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5a')

x = inception_module(x,
                     filters_1x1=384,
                     filters_3x3_reduce=192,
                     filters_3x3=384,
                     filters_5x5_reduce=48,
                     filters_5x5=128,
                     filters_pool_proj=128,
                     name='inception_5b')

x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(38, activation='softmax', name='output')(x)

# %%
model = Model(input_layer, [x, x1, x2], name='inception_v1')

# %%
model.summary()
# Out:
# Model: "inception_v1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 224, 224, 3)  0
# __________________________________________________________________________________________________
# conv_1_7x7/2 (Conv2D)           (None, 112, 112, 64) 9472        input_1[0][0]
# __________________________________________________________________________________________________
# max_pool_1_3x3/2 (MaxPooling2D) (None, 56, 56, 64)   0           conv_1_7x7/2[0][0]
# __________________________________________________________________________________________________
# conv_2a_3x3/1 (Conv2D)          (None, 56, 56, 64)   4160        max_pool_1_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv_2b_3x3/1 (Conv2D)          (None, 56, 56, 192)  110784      conv_2a_3x3/1[0][0]
# __________________________________________________________________________________________________
# max_pool_2_3x3/2 (MaxPooling2D) (None, 28, 28, 192)  0           conv_2b_3x3/1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 28, 28, 96)   18528       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 28, 28, 16)   3088        max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 28, 28, 192)  0           max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 28, 28, 64)   12352       max_pool_2_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 28, 28, 128)  110720      conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 28, 28, 32)   12832       conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 28, 28, 32)   6176        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# inception_3a (Concatenate)      (None, 28, 28, 256)  0           conv2d_1[0][0]
#                                                                  conv2d_3[0][0]
#                                                                  conv2d_5[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 28, 28, 32)   8224        inception_3a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 28, 28, 256)  0           inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 28, 28, 128)  32896       inception_3a[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 28, 28, 192)  221376      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 28, 28, 96)   76896       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 28, 28, 64)   16448       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_3b (Concatenate)      (None, 28, 28, 480)  0           conv2d_7[0][0]
#                                                                  conv2d_9[0][0]
#                                                                  conv2d_11[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# max_pool_3_3x3/2 (MaxPooling2D) (None, 14, 14, 480)  0           inception_3b[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 14, 14, 96)   46176       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 14, 14, 16)   7696        max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 14, 14, 480)  0           max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 14, 14, 192)  92352       max_pool_3_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 14, 14, 208)  179920      conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 14, 14, 48)   19248       conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 14, 14, 64)   30784       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# inception_4a (Concatenate)      (None, 14, 14, 512)  0           conv2d_13[0][0]
#                                                                  conv2d_15[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 14, 14, 112)  57456       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 14, 14, 24)   12312       inception_4a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 14, 14, 160)  82080       inception_4a[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 14, 14, 224)  226016      conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# inception_4b (Concatenate)      (None, 14, 14, 512)  0           conv2d_20[0][0]
#                                                                  conv2d_22[0][0]
#                                                                  conv2d_24[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 14, 14, 24)   12312       inception_4b[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 14, 14, 128)  65664       inception_4b[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 14, 14, 256)  295168      conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 14, 14, 64)   38464       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# inception_4c (Concatenate)      (None, 14, 14, 512)  0           conv2d_26[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_30[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 14, 14, 144)  73872       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 14, 14, 32)   16416       inception_4c[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 14, 14, 512)  0           inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 14, 14, 112)  57456       inception_4c[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 14, 14, 288)  373536      conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 14, 14, 64)   51264       conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 14, 14, 64)   32832       max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# inception_4d (Concatenate)      (None, 14, 14, 528)  0           conv2d_32[0][0]
#                                                                  conv2d_34[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 14, 14, 160)  84640       inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 14, 14, 32)   16928       inception_4d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 14, 14, 528)  0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 14, 14, 256)  135424      inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 14, 14, 320)  461120      conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 14, 14, 128)  102528      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 14, 14, 128)  67712       max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# inception_4e (Concatenate)      (None, 14, 14, 832)  0           conv2d_39[0][0]
#                                                                  conv2d_41[0][0]
#                                                                  conv2d_43[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# max_pool_4_3x3/2 (MaxPooling2D) (None, 7, 7, 832)    0           inception_4e[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 7, 7, 160)    133280      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 7, 7, 32)     26656       max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 7, 7, 832)    0           max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 7, 7, 256)    213248      max_pool_4_3x3/2[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 7, 7, 320)    461120      conv2d_46[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 7, 7, 128)    102528      conv2d_48[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# inception_5a (Concatenate)      (None, 7, 7, 832)    0           conv2d_45[0][0]
#                                                                  conv2d_47[0][0]
#                                                                  conv2d_49[0][0]
#                                                                  conv2d_50[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 7, 7, 192)    159936      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 7, 7, 48)     39984       inception_5a[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_9 (MaxPooling2D)  (None, 7, 7, 832)    0           inception_5a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 4, 4, 512)    0           inception_4a[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_2 (AveragePoo (None, 4, 4, 528)    0           inception_4d[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 7, 7, 384)    319872      inception_5a[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 7, 7, 384)    663936      conv2d_52[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 7, 7, 128)    153728      conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 7, 7, 128)    106624      max_pooling2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 4, 4, 128)    65664       average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 4, 4, 128)    67712       average_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# inception_5b (Concatenate)      (None, 7, 7, 1024)   0           conv2d_51[0][0]
#                                                                  conv2d_53[0][0]
#                                                                  conv2d_55[0][0]
#                                                                  conv2d_56[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 2048)         0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# flatten_2 (Flatten)             (None, 2048)         0           conv2d_38[0][0]
# __________________________________________________________________________________________________
# avg_pool_5_3x3/1 (GlobalAverage (None, 1024)         0           inception_5b[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1024)         2098176     flatten_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1024)         2098176     flatten_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 1024)         0           avg_pool_5_3x3/1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 1024)         0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 1024)         0           dense_2[0][0]
# __________________________________________________________________________________________________
# output (Dense)                  (None, 38)           38950       dropout_3[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_1 (Dense)     (None, 38)           38950       dropout_1[0][0]
# __________________________________________________________________________________________________
# auxilliary_output_2 (Dense)     (None, 38)           38950       dropout_2[0][0]
# ==================================================================================================
# Total params: 10,420,130
# Trainable params: 10,420,130
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
epochs = 25
initial_lrate = 0.005

def decay(epoch, steps=100):
    initial_lrate = 0.005
    drop = 0.96
    epochs_drop = 8
    lrate = initial_lrate * math.pow(drop, math.floor((1+epoch)/epochs_drop))
    return lrate

sgd = SGD(lr=initial_lrate, momentum=0.9, nesterov=True)

lr_sc = LearningRateScheduler(decay, verbose=1)

model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])

# %%
history = model.fit(X_train, [y_train, y_train, y_train], validation_data=(X_test, [y_test, y_test, y_test]), epochs=epochs, batch_size=24, callbacks=[lr_sc])
# Out:
# Train on 14000 samples, validate on 6000 samples
# Epoch 1/25
#
# Epoch 00001: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 370s 26ms/step - loss: 5.4216 - output_loss: 3.3876 - auxilliary_output_1_loss: 3.3849 - auxilliary_output_2_loss: 3.3914 - output_accuracy: 0.1066 - auxilliary_output_1_accuracy: 0.1131 - auxilliary_output_2_accuracy: 0.1037 - val_loss: 5.5293 - val_output_loss: 3.4668 - val_auxilliary_output_1_loss: 3.3628 - val_auxilliary_output_2_loss: 3.5121 - val_output_accuracy: 0.0993 - val_auxilliary_output_1_accuracy: 0.0993 - val_auxilliary_output_2_accuracy: 0.0993
# Epoch 2/25
#
# Epoch 00002: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 385s 27ms/step - loss: 4.8975 - output_loss: 3.0674 - auxilliary_output_1_loss: 3.0425 - auxilliary_output_2_loss: 3.0526 - output_accuracy: 0.1991 - auxilliary_output_1_accuracy: 0.2099 - auxilliary_output_2_accuracy: 0.2089 - val_loss: 4.4210 - val_output_loss: 2.8170 - val_auxilliary_output_1_loss: 2.6553 - val_auxilliary_output_2_loss: 2.6916 - val_output_accuracy: 0.2460 - val_auxilliary_output_1_accuracy: 0.2797 - val_auxilliary_output_2_accuracy: 0.2743
# Epoch 3/25
#
# Epoch 00003: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 365s 26ms/step - loss: 4.1697 - output_loss: 2.6380 - auxilliary_output_1_loss: 2.5255 - auxilliary_output_2_loss: 2.5830 - output_accuracy: 0.2893 - auxilliary_output_1_accuracy: 0.3296 - auxilliary_output_2_accuracy: 0.3108 - val_loss: 3.6731 - val_output_loss: 2.3855 - val_auxilliary_output_1_loss: 2.0803 - val_auxilliary_output_2_loss: 2.2116 - val_output_accuracy: 0.3245 - val_auxilliary_output_1_accuracy: 0.4198 - val_auxilliary_output_2_accuracy: 0.3783
# Epoch 4/25
#
# Epoch 00004: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 359s 26ms/step - loss: 3.3449 - output_loss: 2.1006 - auxilliary_output_1_loss: 2.0581 - auxilliary_output_2_loss: 2.0853 - output_accuracy: 0.4048 - auxilliary_output_1_accuracy: 0.4265 - auxilliary_output_2_accuracy: 0.4204 - val_loss: 2.6447 - val_output_loss: 1.6749 - val_auxilliary_output_1_loss: 1.6046 - val_auxilliary_output_2_loss: 1.6282 - val_output_accuracy: 0.5162 - val_auxilliary_output_1_accuracy: 0.5412 - val_auxilliary_output_2_accuracy: 0.5278
# Epoch 5/25
#
# Epoch 00005: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 357s 26ms/step - loss: 2.5918 - output_loss: 1.6112 - auxilliary_output_1_loss: 1.6213 - auxilliary_output_2_loss: 1.6423 - output_accuracy: 0.5258 - auxilliary_output_1_accuracy: 0.5364 - auxilliary_output_2_accuracy: 0.5296 - val_loss: 2.5497 - val_output_loss: 1.6873 - val_auxilliary_output_1_loss: 1.3548 - val_auxilliary_output_2_loss: 1.5198 - val_output_accuracy: 0.5067 - val_auxilliary_output_1_accuracy: 0.5970 - val_auxilliary_output_2_accuracy: 0.5507
# Epoch 6/25
#
# Epoch 00006: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 358s 26ms/step - loss: 1.9888 - output_loss: 1.2209 - auxilliary_output_1_loss: 1.2664 - auxilliary_output_2_loss: 1.2924 - output_accuracy: 0.6292 - auxilliary_output_1_accuracy: 0.6290 - auxilliary_output_2_accuracy: 0.6188 - val_loss: 1.8265 - val_output_loss: 1.1927 - val_auxilliary_output_1_loss: 1.0036 - val_auxilliary_output_2_loss: 1.1091 - val_output_accuracy: 0.6325 - val_auxilliary_output_1_accuracy: 0.6945 - val_auxilliary_output_2_accuracy: 0.6517
# Epoch 7/25
#
# Epoch 00007: LearningRateScheduler setting learning rate to 0.005.
# 14000/14000 [==============================] - 356s 25ms/step - loss: 1.5278 - output_loss: 0.9198 - auxilliary_output_1_loss: 1.0036 - auxilliary_output_2_loss: 1.0221 - output_accuracy: 0.7131 - auxilliary_output_1_accuracy: 0.6946 - auxilliary_output_2_accuracy: 0.6880 - val_loss: 1.6212 - val_output_loss: 1.0612 - val_auxilliary_output_1_loss: 0.9106 - val_auxilliary_output_2_loss: 0.9558 - val_output_accuracy: 0.6718 - val_auxilliary_output_1_accuracy: 0.7200 - val_auxilliary_output_2_accuracy: 0.7027
# Epoch 8/25
#
# Epoch 00008: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 356s 25ms/step - loss: 1.1987 - output_loss: 0.7049 - auxilliary_output_1_loss: 0.8155 - auxilliary_output_2_loss: 0.8269 - output_accuracy: 0.7729 - auxilliary_output_1_accuracy: 0.7454 - auxilliary_output_2_accuracy: 0.7427 - val_loss: 0.9575 - val_output_loss: 0.5980 - val_auxilliary_output_1_loss: 0.5881 - val_auxilliary_output_2_loss: 0.6105 - val_output_accuracy: 0.7988 - val_auxilliary_output_1_accuracy: 0.8033 - val_auxilliary_output_2_accuracy: 0.8052
# Epoch 9/25
#
# Epoch 00009: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 359s 26ms/step - loss: 0.9895 - output_loss: 0.5737 - auxilliary_output_1_loss: 0.6909 - auxilliary_output_2_loss: 0.6918 - output_accuracy: 0.8117 - auxilliary_output_1_accuracy: 0.7861 - auxilliary_output_2_accuracy: 0.7818 - val_loss: 0.7873 - val_output_loss: 0.4923 - val_auxilliary_output_1_loss: 0.4843 - val_auxilliary_output_2_loss: 0.4992 - val_output_accuracy: 0.8413 - val_auxilliary_output_1_accuracy: 0.8503 - val_auxilliary_output_2_accuracy: 0.8453
# Epoch 10/25
#
# Epoch 00010: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 353s 25ms/step - loss: 0.8172 - output_loss: 0.4619 - auxilliary_output_1_loss: 0.5930 - auxilliary_output_2_loss: 0.5915 - output_accuracy: 0.8424 - auxilliary_output_1_accuracy: 0.8116 - auxilliary_output_2_accuracy: 0.8145 - val_loss: 0.6875 - val_output_loss: 0.4222 - val_auxilliary_output_1_loss: 0.4300 - val_auxilliary_output_2_loss: 0.4543 - val_output_accuracy: 0.8585 - val_auxilliary_output_1_accuracy: 0.8635 - val_auxilliary_output_2_accuracy: 0.8533
# Epoch 11/25
#
# Epoch 00011: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 353s 25ms/step - loss: 0.7092 - output_loss: 0.3977 - auxilliary_output_1_loss: 0.5233 - auxilliary_output_2_loss: 0.5138 - output_accuracy: 0.8708 - auxilliary_output_1_accuracy: 0.8336 - auxilliary_output_2_accuracy: 0.8356 - val_loss: 0.6134 - val_output_loss: 0.3719 - val_auxilliary_output_1_loss: 0.3806 - val_auxilliary_output_2_loss: 0.4245 - val_output_accuracy: 0.8788 - val_auxilliary_output_1_accuracy: 0.8783 - val_auxilliary_output_2_accuracy: 0.8652
# Epoch 12/25
#
# Epoch 00012: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 356s 25ms/step - loss: 0.6225 - output_loss: 0.3470 - auxilliary_output_1_loss: 0.4602 - auxilliary_output_2_loss: 0.4578 - output_accuracy: 0.8861 - auxilliary_output_1_accuracy: 0.8530 - auxilliary_output_2_accuracy: 0.8488 - val_loss: 0.5024 - val_output_loss: 0.2918 - val_auxilliary_output_1_loss: 0.3434 - val_auxilliary_output_2_loss: 0.3588 - val_output_accuracy: 0.9043 - val_auxilliary_output_1_accuracy: 0.8848 - val_auxilliary_output_2_accuracy: 0.8818
# Epoch 13/25
#
# Epoch 00013: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 354s 25ms/step - loss: 0.5404 - output_loss: 0.2966 - auxilliary_output_1_loss: 0.4117 - auxilliary_output_2_loss: 0.4026 - output_accuracy: 0.9013 - auxilliary_output_1_accuracy: 0.8704 - auxilliary_output_2_accuracy: 0.8683 - val_loss: 0.5173 - val_output_loss: 0.3129 - val_auxilliary_output_1_loss: 0.3462 - val_auxilliary_output_2_loss: 0.3351 - val_output_accuracy: 0.8938 - val_auxilliary_output_1_accuracy: 0.8857 - val_auxilliary_output_2_accuracy: 0.8850
# Epoch 14/25
#
# Epoch 00014: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 352s 25ms/step - loss: 0.4619 - output_loss: 0.2461 - auxilliary_output_1_loss: 0.3722 - auxilliary_output_2_loss: 0.3466 - output_accuracy: 0.9181 - auxilliary_output_1_accuracy: 0.8796 - auxilliary_output_2_accuracy: 0.8881 - val_loss: 0.5582 - val_output_loss: 0.3543 - val_auxilliary_output_1_loss: 0.3290 - val_auxilliary_output_2_loss: 0.3508 - val_output_accuracy: 0.8918 - val_auxilliary_output_1_accuracy: 0.8947 - val_auxilliary_output_2_accuracy: 0.8855
# Epoch 15/25
#
# Epoch 00015: LearningRateScheduler setting learning rate to 0.0048.
# 14000/14000 [==============================] - 354s 25ms/step - loss: 0.4131 - output_loss: 0.2182 - auxilliary_output_1_loss: 0.3373 - auxilliary_output_2_loss: 0.3116 - output_accuracy: 0.9260 - auxilliary_output_1_accuracy: 0.8922 - auxilliary_output_2_accuracy: 0.8995 - val_loss: 0.5151 - val_output_loss: 0.3294 - val_auxilliary_output_1_loss: 0.3097 - val_auxilliary_output_2_loss: 0.3092 - val_output_accuracy: 0.8880 - val_auxilliary_output_1_accuracy: 0.8973 - val_auxilliary_output_2_accuracy: 0.8940
# Epoch 16/25
#
# Epoch 00016: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 355s 25ms/step - loss: 0.3655 - output_loss: 0.1906 - auxilliary_output_1_loss: 0.3058 - auxilliary_output_2_loss: 0.2762 - output_accuracy: 0.9376 - auxilliary_output_1_accuracy: 0.8986 - auxilliary_output_2_accuracy: 0.9115 - val_loss: 0.3804 - val_output_loss: 0.2414 - val_auxilliary_output_1_loss: 0.2406 - val_auxilliary_output_2_loss: 0.2229 - val_output_accuracy: 0.9208 - val_auxilliary_output_1_accuracy: 0.9218 - val_auxilliary_output_2_accuracy: 0.9255
# Epoch 17/25
#
# Epoch 00017: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 355s 25ms/step - loss: 0.3070 - output_loss: 0.1575 - auxilliary_output_1_loss: 0.2574 - auxilliary_output_2_loss: 0.2404 - output_accuracy: 0.9471 - auxilliary_output_1_accuracy: 0.9141 - auxilliary_output_2_accuracy: 0.9199 - val_loss: 0.3881 - val_output_loss: 0.2296 - val_auxilliary_output_1_loss: 0.2547 - val_auxilliary_output_2_loss: 0.2736 - val_output_accuracy: 0.9277 - val_auxilliary_output_1_accuracy: 0.9170 - val_auxilliary_output_2_accuracy: 0.9118
# Epoch 18/25
#
# Epoch 00018: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 354s 25ms/step - loss: 0.2998 - output_loss: 0.1552 - auxilliary_output_1_loss: 0.2499 - auxilliary_output_2_loss: 0.2324 - output_accuracy: 0.9471 - auxilliary_output_1_accuracy: 0.9189 - auxilliary_output_2_accuracy: 0.9248 - val_loss: 0.4336 - val_output_loss: 0.2829 - val_auxilliary_output_1_loss: 0.2526 - val_auxilliary_output_2_loss: 0.2497 - val_output_accuracy: 0.9138 - val_auxilliary_output_1_accuracy: 0.9168 - val_auxilliary_output_2_accuracy: 0.9192
# Epoch 19/25
#
# Epoch 00019: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 356s 25ms/step - loss: 0.2691 - output_loss: 0.1357 - auxilliary_output_1_loss: 0.2339 - auxilliary_output_2_loss: 0.2104 - output_accuracy: 0.9552 - auxilliary_output_1_accuracy: 0.9209 - auxilliary_output_2_accuracy: 0.9318 - val_loss: 0.4949 - val_output_loss: 0.3336 - val_auxilliary_output_1_loss: 0.2634 - val_auxilliary_output_2_loss: 0.2742 - val_output_accuracy: 0.8912 - val_auxilliary_output_1_accuracy: 0.9132 - val_auxilliary_output_2_accuracy: 0.9117
# Epoch 20/25
#
# Epoch 00020: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 354s 25ms/step - loss: 0.2351 - output_loss: 0.1159 - auxilliary_output_1_loss: 0.2093 - auxilliary_output_2_loss: 0.1872 - output_accuracy: 0.9604 - auxilliary_output_1_accuracy: 0.9284 - auxilliary_output_2_accuracy: 0.9375 - val_loss: 0.3119 - val_output_loss: 0.1861 - val_auxilliary_output_1_loss: 0.2065 - val_auxilliary_output_2_loss: 0.2129 - val_output_accuracy: 0.9435 - val_auxilliary_output_1_accuracy: 0.9320 - val_auxilliary_output_2_accuracy: 0.9313
# Epoch 21/25
#
# Epoch 00021: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 355s 25ms/step - loss: 0.2369 - output_loss: 0.1204 - auxilliary_output_1_loss: 0.2027 - auxilliary_output_2_loss: 0.1848 - output_accuracy: 0.9596 - auxilliary_output_1_accuracy: 0.9324 - auxilliary_output_2_accuracy: 0.9391 - val_loss: 0.3726 - val_output_loss: 0.2383 - val_auxilliary_output_1_loss: 0.2089 - val_auxilliary_output_2_loss: 0.2387 - val_output_accuracy: 0.9290 - val_auxilliary_output_1_accuracy: 0.9347 - val_auxilliary_output_2_accuracy: 0.9258
# Epoch 22/25
#
# Epoch 00022: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 353s 25ms/step - loss: 0.1983 - output_loss: 0.0952 - auxilliary_output_1_loss: 0.1800 - auxilliary_output_2_loss: 0.1638 - output_accuracy: 0.9671 - auxilliary_output_1_accuracy: 0.9378 - auxilliary_output_2_accuracy: 0.9461 - val_loss: 0.4708 - val_output_loss: 0.3326 - val_auxilliary_output_1_loss: 0.2044 - val_auxilliary_output_2_loss: 0.2563 - val_output_accuracy: 0.9015 - val_auxilliary_output_1_accuracy: 0.9330 - val_auxilliary_output_2_accuracy: 0.9225
# Epoch 23/25
#
# Epoch 00023: LearningRateScheduler setting learning rate to 0.004608.
# 14000/14000 [==============================] - 353s 25ms/step - loss: 0.1876 - output_loss: 0.0918 - auxilliary_output_1_loss: 0.1656 - auxilliary_output_2_loss: 0.1549 - output_accuracy: 0.9692 - auxilliary_output_1_accuracy: 0.9447 - auxilliary_output_2_accuracy: 0.9489 - val_loss: 0.3439 - val_output_loss: 0.2118 - val_auxilliary_output_1_loss: 0.2121 - val_auxilliary_output_2_loss: 0.2282 - val_output_accuracy: 0.9367 - val_auxilliary_output_1_accuracy: 0.9325 - val_auxilliary_output_2_accuracy: 0.9307
# Epoch 24/25
#
# Epoch 00024: LearningRateScheduler setting learning rate to 0.004423679999999999.
# 14000/14000 [==============================] - 350s 25ms/step - loss: 0.1698 - output_loss: 0.0839 - auxilliary_output_1_loss: 0.1564 - auxilliary_output_2_loss: 0.1297 - output_accuracy: 0.9718 - auxilliary_output_1_accuracy: 0.9486 - auxilliary_output_2_accuracy: 0.9559 - val_loss: 0.2997 - val_output_loss: 0.1934 - val_auxilliary_output_1_loss: 0.1714 - val_auxilliary_output_2_loss: 0.1828 - val_output_accuracy: 0.9408 - val_auxilliary_output_1_accuracy: 0.9443 - val_auxilliary_output_2_accuracy: 0.9432
# Epoch 25/25
#
# Epoch 00025: LearningRateScheduler setting learning rate to 0.004423679999999999.
# 14000/14000 [==============================] - 350s 25ms/step - loss: 0.1556 - output_loss: 0.0741 - auxilliary_output_1_loss: 0.1444 - auxilliary_output_2_loss: 0.1271 - output_accuracy: 0.9752 - auxilliary_output_1_accuracy: 0.9506 - auxilliary_output_2_accuracy: 0.9565 - val_loss: 0.2924 - val_output_loss: 0.1829 - val_auxilliary_output_1_loss: 0.1789 - val_auxilliary_output_2_loss: 0.1860 - val_output_accuracy: 0.9433 - val_auxilliary_output_1_accuracy: 0.9428 - val_auxilliary_output_2_accuracy: 0.9393

# %%
final_accuracy = history.history["auxilliary_output_1_accuracy"][-5:]
print("FINAL ACCURACY MEAN-5: ", np.mean(final_accuracy))
# Out:
# FINAL ACCURACY MEAN-5:  0.9427999

# %%
def display_training_curves(training, validation, title, subplot):
  ax = plt.subplot(subplot)
  ax.plot(training)
  ax.plot(validation)
  ax.set_title('Google Net '+ title)
  ax.set_ylabel(title)
  ax.set_xlabel('epoch')
  ax.legend(['training', 'validation'])

plt.subplots(figsize=(10,10))
plt.tight_layout()
display_training_curves(history['output_accuracy'], history['val_output_accuracy'], 'accuracy', 211)
display_training_curves(history['loss'], history['val_loss'], 'loss', 212)

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model')

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model.save_weights("model.h5")

# %%
from keras.models import model_from_json

json_file = open('model.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model = model_from_json(loaded_model_json)
# load weights into new model
loaded_model.load_weights("model.h5")
print("Loaded model from disk")
 
loaded_model.compile(loss=['categorical_crossentropy', 'categorical_crossentropy', 'categorical_crossentropy'], loss_weights=[1, 0.3, 0.3], optimizer=sgd, metrics=['accuracy'])


score = loaded_model.evaluate(X_test, y_test, verbose=0)
print("%s: %.2f%%" % (loaded_model.metrics_names[1], score[1]*100))

# %%
with open('file.json', 'w') as f:
    json.dump(hist.history, f)
